# %%
import pandas as pd
df2 = pd.read_excel(r'/Users/laharigoshika/Downloads/Combined-1.xlsx', sheet_name='Pasco')

# %%
df2.columns = ['Date', 'Daily Number', 'Moving Average']
print(df2)
# Out:
#           Date  Daily Number  Moving Average
# 0   2020-03-01             2             2.0
# 1   2020-03-02             1             1.5
# 2   2020-03-07             2             1.7
# 3   2020-03-08             3             2.0
# 4   2020-03-09             5             2.6
# ..         ...           ...             ...
# 362 2021-03-02            60            88.8
# 363 2021-03-03            64            81.8
# 364 2021-03-04            47            72.0
# 365 2021-03-05            29            65.3
# 366 2021-03-06            64            61.3
#
# [367 rows x 3 columns]

# %%
df2.plot('Date', ['Daily Number', 'Moving Average'])
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df2
df2.plot('Date', ['Daily Number', 'Moving Average'], xticks=[])
# Out:
# <AxesSubplot:xlabel='Date'>
