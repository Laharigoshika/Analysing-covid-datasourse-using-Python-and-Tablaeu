# %%
import pandas as pd

# %%
new_df= pd.read_excel(r'/Users/laharigoshika/Downloads/2018 Data-1.xlsx')
print(new_df.columns)
# Out:
# Index(['NAME', 'Unemployment Rate', 'Median Family Income',
#        'Mean Family Income', 'Per Capita Income', 'Perc with health Insurance',
#        'Perc Families below Poverty Line', 'Perc People below Poverty Line',
#        'Obesity Rates'],
#       dtype='object')

# %%
new_df.plot('Mean Family Income','Perc with health Insurance', kind='scatter', marker='*', c='green')
# Out:
# <AxesSubplot:xlabel='Mean Family Income', ylabel='Perc with health Insurance'>
