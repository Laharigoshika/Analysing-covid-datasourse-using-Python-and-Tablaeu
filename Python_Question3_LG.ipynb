# %%
import pandas as pd
df2 = pd.read_excel(r'/Users/laharigoshika/Downloads/Combined-1.xlsx', sheet_name='Hillsborough')
df2.columns = ['Date', 'Daily Number', 'Moving Average']

df2.plot('Date', ['Daily Number'], xticks=[], color='green')
df2.plot('Date', ['Moving Average'], xticks=[], kind='bar', width = 1)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
import pandas as pd

df2 = pd.read_excel(r'/Users/laharigoshika/Downloads/Combined-1.xlsx', sheet_name='Hillsborough')

df2.columns = ['Date', 'Daily Number', 'Moving Average']

axes = df2.plot('Date', ['Daily Number'], xticks=[], color='green')
df2.plot('Date', ['Moving Average'], xticks=[], kind='bar', width = 1, ax = axes)
# Out:
# <AxesSubplot:xlabel='Date'>
